# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"XCor ir.xlsx")

# %%
df.head()
# Out:
#      IR1    IR2    IR3    IR4    IR5    IR6
# 0  95.68  95.81  95.94  96.08  96.19  96.26
# 1  95.68  95.80  95.93  96.08  96.18  96.26
# 2  95.68  95.80  95.95  96.07  96.18  96.25
# 3  95.68  95.80  95.93  96.06  96.19  96.25
# 4  95.69  95.81  95.93  96.06  96.18  96.25

# %%
df.corr()
# Out:
#           IR1       IR2       IR3       IR4       IR5       IR6
# IR1  1.000000 -0.019497 -0.105177 -0.317184 -0.148344  0.454598
# IR2 -0.019497  1.000000  0.884114  0.522756  0.732549  0.702270
# IR3 -0.105177  0.884114  1.000000  0.666963  0.872373  0.558727
# IR4 -0.317184  0.522756  0.666963  1.000000  0.811232  0.179883
# IR5 -0.148344  0.732549  0.872373  0.811232  1.000000  0.459924
# IR6  0.454598  0.702270  0.558727  0.179883  0.459924  1.000000

# %% [markdown]
# #####

# %%
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='coolwarm')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
# save heatmap as .png file
# dpi - sets the resolution of the saved image in dots/inches
# bbox_inches - when set to 'tight' - does not allow the labels to be cropped
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
