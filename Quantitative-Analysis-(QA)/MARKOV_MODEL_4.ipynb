# %%
import pandas as pd

# %%
df = pd.read_excel("IR Dec25_Cluster_Analysis.xlsx")

# %%
df.head()
# Out:
#       Timestamp (UTC)    hl    oc  hl-oc    hl/vol  Volume  5DayRollingStdDev  \
# 0 2024-02-08 06:08:00  0.04  0.01   0.03  0.000082     489           0.013038
# 1 2024-02-08 14:08:00  0.02  0.02   0.00  0.000127     157           0.019235
# 2 2024-02-08 21:28:00  0.04  0.02   0.02  0.000037    1077           0.022804
# 3 2024-02-09 05:28:00  0.00  0.00   0.00  0.000000       5           0.016733
# 4 2024-02-09 06:08:00  0.04  0.03   0.01  0.000028    1436           0.022804
#
#    Cluster
# 0        0
# 1        0
# 2        3
# 3        0
# 4        2

# %% [markdown]
# ## 1. Get **Previous State**
# **using .shift(1) on "Cluster" column**

# %%
df['previous_state'] = df['Cluster'].shift(1)

# %%
df.head()
# Out:
#       Timestamp (UTC)    hl    oc  hl-oc    hl/vol  Volume  5DayRollingStdDev  \
# 0 2024-02-08 06:08:00  0.04  0.01   0.03  0.000082     489           0.013038
# 1 2024-02-08 14:08:00  0.02  0.02   0.00  0.000127     157           0.019235
# 2 2024-02-08 21:28:00  0.04  0.02   0.02  0.000037    1077           0.022804
# 3 2024-02-09 05:28:00  0.00  0.00   0.00  0.000000       5           0.016733
# 4 2024-02-09 06:08:00  0.04  0.03   0.01  0.000028    1436           0.022804
#
#    Cluster  previous_state
# 0        0             NaN
# 1        0             0.0
# 2        3             0.0
# 3        0             3.0
# 4        2             0.0

# %%
# drop first row
df1=df.dropna()
df1 = df1.copy()  # Make an explicit copy of the DataFrame

# %%
# converting 'previous_state' from float to int
df1['previous_state'] = df1['previous_state'].astype(int)

# %%
#df1.head()

# %% [markdown]
# ## 2. Creating **Transition States**

# %%
df1['c_states'] = df1['previous_state'].astype(str) + df1['Cluster'].astype(str)

# %%
df1.head(10)
# Out:
#        Timestamp (UTC)    hl    oc  hl-oc    hl/vol  Volume  \
# 1  2024-02-08 14:08:00  0.02  0.02   0.00  0.000127     157
# 2  2024-02-08 21:28:00  0.04  0.02   0.02  0.000037    1077
# 3  2024-02-09 05:28:00  0.00  0.00   0.00  0.000000       5
# 4  2024-02-09 06:08:00  0.04  0.03   0.01  0.000028    1436
# 5  2024-02-09 14:08:00  0.05  0.02   0.03  0.000099     505
# 6  2024-02-11 21:28:00  0.03  0.00   0.03  0.000046     655
# 7  2024-02-12 06:08:00  0.01  0.00   0.01  0.000095     105
# 8  2024-02-12 14:08:00  0.01  0.01   0.00  0.000070     143
# 9  2024-02-12 21:28:00  0.03  0.00   0.03  0.000019    1547
# 10 2024-02-13 05:28:00  0.01  0.00   0.01  0.000208      48
#
#     5DayRollingStdDev  Cluster  previous_state c_states
# 1            0.019235        0               0       00
# 2            0.022804        3               0       03
# 3            0.016733        0               3       30
# 4            0.022804        2               0       02
# 5            0.030332        0               2       20
# 6            0.031145        3               0       03
# 7            0.031145        0               3       30
# 8            0.015811        0               0       00
# 9            0.011402        2               0       02
# 10           0.010954        0               2       20

# %% [markdown]
# ## 3. Grouping by Transition state and Counting occurrences

# %%
states = df1.groupby('c_states')['c_states'].value_counts().fillna(0).reset_index()

# %%
states
# Out:
#    c_states  count
# 0        00     20
# 1        01      1
# 2        02     21
# 3        03     24
# 4        10      4
# 5        20     18
# 6        22      4
# 7        23      8
# 8        30     24
# 9        31      3
# 10       32      5
# 11       33     10

# %% [markdown]
# ## 4. Separate the transition state
# **'previous' and 'present' state to 'start' and 'end' state**

# %%
# Extract start and end states from `c_states`
states["start_state"] = states["c_states"].str[0].astype(int)
states["end_state"] = states["c_states"].str[1].astype(int)

# %%
states
# Out:
#    c_states  count  start_state  end_state
# 0        00     20            0          0
# 1        01      1            0          1
# 2        02     21            0          2
# 3        03     24            0          3
# 4        10      4            1          0
# 5        20     18            2          0
# 6        22      4            2          2
# 7        23      8            2          3
# 8        30     24            3          0
# 9        31      3            3          1
# 10       32      5            3          2
# 11       33     10            3          3

# %% [markdown]
# ## 5. Create **Markov transition matrix**

# %%
# Create the Markov transition matrix
transition_matrix = states.pivot(index="start_state", columns="end_state", values="count").fillna(0)

# %%
transition_matrix
# Out:
# end_state       0    1     2     3
# start_state
# 0            20.0  1.0  21.0  24.0
# 1             4.0  0.0   0.0   0.0
# 2            18.0  0.0   4.0   8.0
# 3            24.0  3.0   5.0  10.0

# %% [markdown]
# ## 6. Convert to row-wise percentages

# %%
transition_matrix_perc = transition_matrix.div(transition_matrix.sum(axis=1), axis=0) * 100

# %%
transition_matrix_perc.round(2)
# Out:
# end_state         0     1      2      3
# start_state
# 0             30.30  1.52  31.82  36.36
# 1            100.00  0.00   0.00   0.00
# 2             60.00  0.00  13.33  26.67
# 3             57.14  7.14  11.90  23.81

# %% [markdown]
# **Applications:**

# %% [markdown]
# Prediction: Predict the next state of the market based on the current state (i.e., forecasting the market's behavior).
#
# Optimization: Use the Markov Model for portfolio optimization, where states represent different market conditions, and transitions model how the market shifts.
#
# Risk Assessment: Assess the risk of being in a certain state at a future time.
